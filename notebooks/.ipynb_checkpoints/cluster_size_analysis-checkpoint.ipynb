# %%
import matplotlib.pyplot as plt
import matplotlib.cm
import numpy as np
import math
import random
import pandas as pd
import matplotlib as mpl

# %%
df = pd.read_csv("9500massv3.csv")
display(df)
# Out:
#                                      centroid_positions  cluster_mass  \
# 0     [0.8760955929756165, 0.9804202914237976, 0.558...      0.032769
# 1     [0.9194476008415222, 0.9277634620666504, 0.576...      0.031831
# 2     [0.5803011059761047, 0.8098230361938477, 0.760...      0.027664
# 3     [0.7522434592247009, 0.530567467212677, 0.5513...      0.021949
# 4     [0.9913035035133362, 0.8930765390396118, 0.698...      0.025902
# ...                                                 ...           ...
# 9495  [0.5329102277755737, 0.5101433396339417, 0.580...      0.032166
# 9496  [0.6704057455062866, 0.5192597508430481, 0.509...      0.028090
# 9497  [0.8791456818580627, 0.8067240715026855, 0.503...      0.031844
# 9498  [0.8272271752357483, 0.9533138871192932, 0.592...      0.029079
# 9499  [0.8815082907676697, 0.8904386162757874, 0.539...      0.020355
#
#                                       centroid_filepath  \
# 0     /media/andrius/FastBoi/bakis_data/final22k/tra...
# ...

# %%
sizes = []
for size in df["cluster_mass"]:
    sizes.append(size)
sizes = np.array(sizes)
print(f"mean={sizes.mean()}")
print(f"median={np.median(sizes)}")
print(f"min={sizes.min()}")
print(f"max={sizes.max()}")
print(f"stdev={sizes.std()}")
# Out:
# mean=0.02830695344664544
# median=0.02877584192901845
# min=0.0091434968635439
# max=0.0425379686057567
# stdev=0.004262009465933708

# %%
df = df.sort_values(by=['cluster_mass'])
for row in df.tail().itertuples():
    print(f"{row.centroid_filepath} -> {row.cluster_mass}")
# Out:
# /media/andrius/FastBoi/bakis_data/final22k/train/Mike Oldfield - Tubular Bells - Pt. I.mp3 -> 0.0418711379170417
# /media/andrius/FastBoi/bakis_data/final22k/train/Yes - Close to the Edge (i. The Solid Time of Change, ii. Total Mass Retain, iii. I Get up I Get Down, iv. Seasons of Man) - 2003 Remaster.mp3 -> 0.0419339686632156
# /media/andrius/FastBoi/bakis_data/final22k/train/Brian Eno - 11 - Remastered 2004.mp3 -> 0.041970208287239
# /media/andrius/FastBoi/bakis_data/final22k/train/Sigur Rós - Viðrar Vel til Loftárása.mp3 -> 0.0423089936375618
# /media/andrius/FastBoi/bakis_data/final22k/train/Keith Jarrett - Köln, January 24, 1975, Part I.mp3 -> 0.0425379686057567

# %%
size_variation_df_wd = pd.read_csv("./cluster_variation_experiment_wd.csv")
size_variation_df = pd.read_csv("./cluster_variation_experiment.csv")
def transform_size_variation_df(df):
    df["song_under_test_accuracy"] = df["song_under_test_correct_samples"] / df["song_under_test_total_samples"]
    df["song_under_test_top5_accuracy"] = df["song_under_test_top5_correct_samples"] / df["song_under_test_total_samples"]
    df["others_accuracy"] = df["other_correct_samples"] / df["other_total_samples"]
    df["others_top5_accuracy"] = df["other_top5_correct_samples"] / df["other_total_samples"]
    return df
size_variation_df_wd = transform_size_variation_df(size_variation_df_wd)
size_variation_df = transform_size_variation_df(size_variation_df)
display(size_variation_df_wd)
# Out:
#     Unnamed: 0  song_under_test_total_samples  \
# 0            0                            151
# 1            1                            151
# 2            2                            151
# 3            3                            151
# 4            4                            151
# ..         ...                            ...
# 95          95                            151
# 96          96                            151
# 97          97                            151
# 98          98                            151
# 99          99                            151
#
#     song_under_test_correct_samples  song_under_test_top5_correct_samples  \
# 0                               149                                   149
# 1                               149                                   149
# 2                               149                                   149
# 3                               149                                   149
# ...

# %%
fig = plt.figure(figsize=(10,6))
fig.suptitle("Accuracy measurements when shrinking test song cluster mass")
plt.plot(size_variation_df['cluster_reduction'], size_variation_df['song_under_test_accuracy'], label='test song')
plt.plot(size_variation_df['cluster_reduction'], size_variation_df['song_under_test_top5_accuracy'], label='test song top5')
# plt.plot(size_variation_df['cluster_reduction'], size_variation_df['others_accuracy'], label='others')
# plt.plot(size_variation_df['cluster_reduction'], size_variation_df['others_top5_accuracy'], label='others top5')

plt.plot(size_variation_df_wd['cluster_reduction'], size_variation_df_wd['song_under_test_accuracy'], label='wd test song')
plt.plot(size_variation_df_wd['cluster_reduction'], size_variation_df_wd['song_under_test_top5_accuracy'], label='wd test song top5')
# plt.plot(size_variation_df_wd['cluster_reduction'], size_variation_df_wd['others_accuracy'], label='wd others')
# plt.plot(size_variation_df_wd['cluster_reduction'], size_variation_df_wd['others_top5_accuracy'], label='wd others top5')
plt.xlabel('Size reduction, %')
plt.ylabel('Accuracy, %')
plt.legend()

# %%
def show_heatmap(df):
    cmap = plt.get_cmap('plasma')
    patches = []
    for size_reduction in np.linspace(0,1, 10):
        accuracy = df[df['cluster_reduction'] > size_reduction]['song_under_test_accuracy'].max()
        base_size = 45
        circle = plt.Circle((50, 50), base_size-base_size*size_reduction, color=cmap(accuracy))
        patches.append(circle)
    fig, ax = plt.subplots(figsize=(10,14)) # note we must use plt.subplots, not plt.subplot
    ax.set_xlim(0, 100)
    ax.set_ylim(0, 100)
    for p in patches:
        ax.add_patch(p)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    norm = mpl.colors.Normalize(vmin=0, vmax=100)
    fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
                 orientation='horizontal', label='Accuracy, %')
    plt.tight_layout()
    plt.show()
show_heatmap(size_variation_df)

# %%
show_heatmap(size_variation_df_wd)
